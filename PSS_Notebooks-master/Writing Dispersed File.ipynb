# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
import VersionZeroPointZero as PSS
from scipy import signal
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#dispersion measure
dispersionMeasure = 40
# bandwidth
bandwidth = 40
# total time
totalTime = 50

# make signal
signal1 = PSS.Signal(TotTime = totalTime, bw = bandwidth, SignalType = 'voltage', data_type = 'int16')

# instantiate pulsar, create pulse
pulsar = PSS.Pulsar(signal1)
pulsar.make_pulses()

# create intersteller medium, apply dispersion and store signal
ism = PSS.ISM(signal1, DM = dispersionMeasure)
ism.disperse()
dispersedSignal = ism.signal;

# %%
plt.figure(figsize=[10,4])
plt.title("Raw Pulsar Data representing voltage vs time")
plt.ylabel("Voltage")
plt.xlabel("Time")
plt.plot(dispersedSignal[0,:])
plt.show()

# %%
print
psrSigFileDispersed = open('../PulsarSignalOutputs/pulsarSignalFileDispersed.bin', 'wb')
psrSigFileDispersed.write(bytes(newSig[0,:]))
# pickle
# cast to int32, maybe float32
# Out:
# 2000
